# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/Users/tejastammewar/Desktop/aiml/datasets/Titanic-Dataset.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %% [markdown]
# # Handling null values

# %%
df.isnull().any()
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Age']=df['Age'].fillna(df['Age'].mean())

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df['Embarked']=df['Embarked'].fillna(df['Embarked'].mode()[0])

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %% [markdown]
# # Data Visualization

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %%
sns.distplot(df['Age'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.barplot(x=df['Sex'],y=df['Survived'],ci=None)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Survived'>

# %%
plt.figure(figsize=(25,8))
sns.barplot(x=df['Age'],y=df['Survived'],ci=None)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Survived'>

# %%
dff=df

# %% [markdown]
# # Outlier detection

# %%
sns.boxplot(df["Age"])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %%
sns.boxplot(df["SibSp"])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SibSp'>

# %% [markdown]
# # Outlier removal in Age using IQR

# %%
q1=df.Age.quantile(0.25)
q3=df.Age.quantile(0.75)
print(q1)
print(q3)
# Out:
# 22.0
# 35.0

# %%
IQR=q3-q1
IQR
# Out:
# 13.0

# %%
upper_limit=q3+1.5*IQR
upper_limit
# Out:
# 54.5

# %%
lower_limit=q3-1.5*IQR
lower_limit
# Out:
# 15.5

# %%
df=df[df.Age>lower_limit]

# %%
df=df[df.Age<upper_limit]

# %%
sns.boxplot(df.Age)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %%
df.shape
# Out:
# (766, 12)

# %% [markdown]
# # Outlier removal in SibSp using zscore

# %%
from scipy import stats

# %%
sibsp_zscore=stats.zscore(df.SibSp)
sibsp_zscore
# Out:
# 0      0.606095
# 1      0.606095
# 2     -0.425613
# 3      0.606095
# 4     -0.425613
#          ...
# 886   -0.425613
# 887   -0.425613
# 888    0.606095
# 889   -0.425613
# 890   -0.425613
# Name: SibSp, Length: 766, dtype: float64

# %%
df_z=df[np.abs(sibsp_zscore)<=3]

# %%
sns.boxplot(df_z.SibSp)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='SibSp'>

# %% [markdown]
# # replacong outliers in Fare using IQR

# %%
sns.boxplot(df["Fare"])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Fare'>

# %%
q1=df.Fare.quantile(0.25)
q3=df.Fare.quantile(0.75)

# %%
print(q1)
print(q3)
# Out:
# 7.8958
# 29.55625

# %%
IQR=q3-q1

# %%
whisker_width = 1.5
lower_whisker = q1 -(whisker_width*IQR)
upper_whisker = q3 + (whisker_width*IQR)

# %%
df['Fare']=np.where(df['Fare']>upper_whisker,upper_whisker,
                    np.where(df['Fare']<lower_whisker,lower_whisker,df['Fare']))

# %%
sns.boxplot(df['Fare'],data=df)
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Fare'>

# %%
sns.boxplot(df["Parch"])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Parch'>

# %%
q1=df.Parch.quantile(0.25)
q3=df.Parch.quantile(0.75)
print(q1)
print(q3)
# Out:
# 0.0
# 0.0

# %%
sns.boxplot(df["PassengerId"]) #no outliers
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='PassengerId'>

# %%
sns.boxplot(df['Pclass'])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Pclass'>

# %% [markdown]
# # Dropping extra columns

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df=df.drop(columns=['Name','Ticket','Cabin','PassengerId'],axis=1)
df
# Out:
#      Survived  Pclass     Sex        Age  SibSp  Parch       Fare Embarked
# 0           0       3    male  22.000000      1      0   7.250000        S
# 1           1       1  female  38.000000      1      0  62.046925        C
# 2           1       3  female  26.000000      0      0   7.925000        S
# 3           1       1  female  35.000000      1      0  53.100000        S
# 4           0       3    male  35.000000      0      0   8.050000        S
# ..        ...     ...     ...        ...    ...    ...        ...      ...
# 886         0       2    male  27.000000      0      0  13.000000        S
# 887         1       1  female  19.000000      0      0  30.000000        S
# 888         0       3  female  29.699118      1      2  23.450000        S
# 889         1       1    male  26.000000      0      0  30.000000        C
# 890         0       3    male  32.000000      0      0   7.750000        Q
#
# [766 rows x 8 columns]

# %% [markdown]
# # Splitting dependent and independent

# %%
#independent-->2d or dataframe
x=df.drop(columns=['Survived'],axis=1)
x
# Out:
#      Pclass     Sex        Age  SibSp  Parch       Fare Embarked
# 0         3    male  22.000000      1      0   7.250000        S
# 1         1  female  38.000000      1      0  62.046925        C
# 2         3  female  26.000000      0      0   7.925000        S
# 3         1  female  35.000000      1      0  53.100000        S
# 4         3    male  35.000000      0      0   8.050000        S
# ..      ...     ...        ...    ...    ...        ...      ...
# 886       2    male  27.000000      0      0  13.000000        S
# 887       1  female  19.000000      0      0  30.000000        S
# 888       3  female  29.699118      1      2  23.450000        S
# 889       1    male  26.000000      0      0  30.000000        C
# 890       3    male  32.000000      0      0   7.750000        Q
#
# [766 rows x 7 columns]

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 766 entries, 0 to 890
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    766 non-null    int64
#  1   Sex       766 non-null    object
#  2   Age       766 non-null    float64
#  3   SibSp     766 non-null    int64
#  4   Parch     766 non-null    int64
#  5   Fare      766 non-null    float64
#  6   Embarked  766 non-null    object
# dtypes: float64(2), int64(3), object(2)
# memory usage: 47.9+ KB

# %%
x.shape
# Out:
# (766, 7)

# %%
y=df["Survived"]
type(y)
# Out:
# pandas.core.series.Series

# %% [markdown]
# # Encoding

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
x['Sex']=le.fit_transform(x["Sex"])

# %%
print(le.classes_)
# Out:
# ['female' 'male']

# %%
mapping=dict(zip(le.classes_,range(len(le.classes_))))
mapping
# Out:
# {'female': 0, 'male': 1}

# %%
x['Embarked']=le.fit_transform(x["Embarked"])

# %%
print(le.classes_)
# Out:
# ['C' 'Q' 'S']

# %%
mapping=dict(zip(le.classes_,range(len(le.classes_))))
mapping
# Out:
# {'C': 0, 'Q': 1, 'S': 2}

# %%
x.head()
# Out:
#    Pclass  Sex   Age  SibSp  Parch       Fare  Embarked
# 0       3    1  22.0      1      0   7.250000         2
# 1       1    0  38.0      1      0  62.046925         0
# 2       3    0  26.0      0      0   7.925000         2
# 3       1    0  35.0      1      0  53.100000         2
# 4       3    1  35.0      0      0   8.050000         2

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
ms=MinMaxScaler()

# %%
x_scaled=pd.DataFrame(ms.fit_transform(x),columns=x.columns)

# %%
x_scaled.head()
# Out:
#    Pclass  Sex       Age  SibSp  Parch      Fare  Embarked
# 0     1.0  1.0  0.157895  0.125    0.0  0.116847       1.0
# 1     0.0  0.0  0.578947  0.125    0.0  1.000000       0.0
# 2     1.0  0.0  0.263158  0.000    0.0  0.127726       1.0
# 3     0.0  0.0  0.500000  0.125    0.0  0.855804       1.0
# 4     1.0  1.0  0.500000  0.000    0.0  0.129741       1.0

# %% [markdown]
# # Train test Split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x_scaled,y,test_size=0.2,random_state=0)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (612, 7)
# (154, 7)
# (612,)
# (154,)

# %%
x_train.head()
# Out:
#      Pclass  Sex       Age  SibSp  Parch      Fare  Embarked
# 479     1.0  1.0  0.360503  0.000    0.0  0.124905       0.5
# 118     1.0  0.0  0.210526  0.125    0.0  0.255452       1.0
# 247     1.0  1.0  0.210526  0.000    0.0  0.127255       1.0
# 157     1.0  0.0  0.078947  0.125    0.0  0.126585       1.0
# 467     0.5  0.0  0.078947  0.125    0.0  0.419038       1.0

# %%
x_test.head()
# Out:
#      Pclass  Sex       Age  SibSp  Parch      Fare  Embarked
# 685     0.5  1.0  0.605263  0.000    0.0  0.209519       1.0
# 122     1.0  1.0  0.289474  0.000    0.0  0.125644       1.0
# 113     0.0  1.0  0.552632  0.125    0.0  0.855804       1.0
# 14      0.5  1.0  0.473684  0.000    0.0  0.209519       1.0
# 612     0.0  1.0  0.360503  0.000    0.0  0.427902       1.0
